# %%
import pandas as pd
data = open('rest.csv','r')#,encoding="utf8")
print(data)
p = pd.read_csv(data)
p.head()
#p['Name']
# print(data.read(69532)[69512-40:69512+10])
# Out:
# <_io.BufferedReader name='rest.csv'>
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 22: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-93-6469998bf078> in <module>()
#       2 data = open('rest.csv','rb')#,encoding="utf8")
#       3 print(data)
# ----> 4 p = pd.read_csv(data)
#       5 p.head()
#       6 #p['Name']
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     409
#     410     try:
# --> 411         data = parser.read(nrows)
#     412     finally:
#     413         parser.close()
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1003                 raise ValueError('skipfooter not supported for iteration')
#    1004
# -> 1005         ret = self._engine.read(nrows)
#    1006
#    1007         if self.options.get('as_recarray'):
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1746     def read(self, nrows=None):
#    1747         try:
# -> 1748             data = self._reader.read(nrows)
#    1749         except StopIteration:
#    1750             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read (pandas\_libs\parsers.c:10862)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory (pandas\_libs\parsers.c:11138)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows (pandas\_libs\parsers.c:12175)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data (pandas\_libs\parsers.c:14136)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas\_libs\parsers.c:14972)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas\_libs\parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas\_libs\parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas\_libs\parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 22: invalid start byte

# %%
p.Name=p.Name.fillna('Afghanistan')

# %%
n=p['Name']
l=[]
for name in n:
    l.append(name)
m=list(set(l))

# %%
from geopy.geocoders import Nominatim
lat=[]
lon=[]
for names in l:
    geolocator = Nominatim(user_agent="specify_your_app_name_here")
    location = geolocator.geocode(names,timeout=1000000)
    #print((location.latitude, location.longitude))
    if location:
        lat.append(location.latitude)
        lon.append(location.longitude)
    else:
        lat.append(33.7680065)
        lon.append(66.2385139)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     343         try:
# --> 344             page = requester(req, timeout=timeout, **kwargs)
#     345         except Exception as error:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     465
# --> 466         response = self._open(req, data)
#     467
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\urllib\request.py in _open(self, req, data)
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\urllib\request.py in https_open(self, req)
#    1296             return self.do_open(http.client.HTTPSConnection, req,
# -> 1297                 context=self._context, check_hostname=self._check_hostname)
#    1298
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\http\client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\socket.py in readinto(self, b)
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\ssl.py in read(self, len, buffer)
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\ssl.py in read(self, len, buffer)
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-65-90cd710e3617> in <module>()
#       4 for names in l:
#       5     geolocator = Nominatim(user_agent="specify_your_app_name_here")
# ----> 6     location = geolocator.geocode(names,timeout=1000000)
#       7     #print((location.latitude, location.longitude))
#       8     if location:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\geopy\geocoders\osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags)
#     305
#     306         return self._parse_json(
# --> 307             self._call_geocoder(url, timeout=timeout), exactly_one
#     308         )
#     309
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     373                 if "timed out" in message:
#     374                     raise GeocoderTimedOut('Service timed out')
# --> 375             raise GeocoderServiceError(message)
#     376
#     377         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: 10054

# %%
# from geopy.exc import GeocoderTimedOut

# geolocator = Nominatim()
# try:
#     location = geolocator.geocode("Angullia",timeout=None)
#     print(location.latitude, location.longitude)
# except GeocoderTimedOut as e:
#     print("Error: geocode failed on input %s with message %s"%(my_address, e.message))

# %%
import pandas as pd
se = pd.Series(lat)
p['latitude'] = se.values


#p.append(lat,column=['latitude'])
#p.append(lon,column=['longitude'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-d96e3809178a> in <module>()
#       1 import pandas as pd
#       2 se = pd.Series(lat)
# ----> 3 p['latitude'] = se.values
#       4
#       5
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# -> 2568             value = _sanitize_index(value, self.index, copy=False)
#    2569             if not isinstance(value, (np.ndarray, Index)):
#    2570                 if isinstance(value, list) and len(value) > 0:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\series.py in _sanitize_index(data, index, copy)
#    2877
#    2878     if len(data) != len(index):
# -> 2879         raise ValueError('Length of values does not match length of ' 'index')
#    2880
#    2881     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
se = pd.Series(lon)
p['longitude'] = se.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-ea8bd867da03> in <module>()
#       1 se = pd.Series(lon)
# ----> 2 p['longitude'] = se.values
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# -> 2568             value = _sanitize_index(value, self.index, copy=False)
#    2569             if not isinstance(value, (np.ndarray, Index)):
#    2570                 if isinstance(value, list) and len(value) > 0:
#
# C:\Users\Mayank\AppData\Local\Enthought\Canopy\edm\envs\User\lib\site-packages\pandas\core\series.py in _sanitize_index(data, index, copy)
#    2877
#    2878     if len(data) != len(index):
# -> 2879         raise ValueError('Length of values does not match length of ' 'index')
#    2880
#    2881     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
p
# Out:
#      ISO3         Name  Year Start Date  \
# 0     AFG  Afghanistan  2008   01-08-08
# 1     AFG  Afghanistan  2008   17-04-08
# 2     AFG  Afghanistan  2008   01-01-08
# 3     AFG  Afghanistan  2009   01-01-09
# 4     AFG  Afghanistan  2009   01-01-09
# 5     AFG  Afghanistan  2009   01-01-09
# 6     AFG  Afghanistan  2009   01-01-09
# 7     AFG  Afghanistan  2010   01-01-10
# 8     AFG  Afghanistan  2010   01-01-10
# 9     AFG  Afghanistan  2010   01-01-10
# 10    AFG  Afghanistan  2010   01-01-10
# 11    AFG  Afghanistan  2010   01-01-10
# 12    AFG  Afghanistan  2011   01-01-11
# 13    AFG  Afghanistan  2012   01-01-12
# 14    AFG  Afghanistan  2012   01-01-12
# 15    AFG  Afghanistan  2012   01-01-12
# 16    AFG  Afghanistan  2012   01-01-12
# 17    AFG  Afghanistan  2012   01-01-12
# 18    AFG  Afghanistan  2012   01-01-12
# 19    AFG  Afghanistan  2012   01-01-12
# 20    AFG  Afghanistan  2012   01-01-12
# 21    AFG  Afghanistan  2012   01-01-12
# 22    AFG  Afghanistan  2012   01-01-12
# 23    AFG  Afghanistan  2013   01-03-13
# 24    AFG  Afghanistan  2013   15-04-13
# 25    AFG  Afghanistan  2013   24-11-13
# 26    AFG  Afghanistan  2013   03-08-13
# 27    AFG  Afghanistan  2013   01-02-13
# 28    AFG  Afghanistan  2014   20-04-14
# 29    AFG  Afghanistan  2014   06-06-14
# ...   ...          ...   ...        ...
# 4786  ZMB       Zambia  2017   16-11-17
# 4787  ZMB       Zambia  2017   31-12-17
# 4788  ZMB       Zambia  2017   14-12-17
# 4789  ZMB       Zambia  2017   24-02-17
# 4790  ZMB       Zambia  2017   07-02-17
# 4791  ZMB       Zambia  2017   13-03-17
# 4792  ZWE     Zimbabwe  2010   01-01-10
# 4793  ZWE     Zimbabwe  2011   01-01-11
# 4794  ZWE     Zimbabwe  2013   17-01-13
# 4795  ZWE     Zimbabwe  2014   01-01-14
# 4796  ZWE     Zimbabwe  2014   01-04-14
# 4797  ZWE     Zimbabwe  2014   01-02-14
# 4798  ZWE     Zimbabwe  2014   01-10-14
# 4799  ZWE     Zimbabwe  2014   01-10-14
# 4800  ZWE     Zimbabwe  2014   01-12-14
# 4801  ZWE     Zimbabwe  2014   01-12-14
# 4802  ZWE     Zimbabwe  2014   01-11-14
# 4803  ZWE     Zimbabwe  2014   01-10-14
# 4804  ZWE     Zimbabwe  2014   01-10-14
# 4805  ZWE     Zimbabwe  2014   17-12-14
# 4806  ZWE     Zimbabwe  2014   01-08-14
# 4807  ZWE     Zimbabwe  2014   01-02-14
# 4808  ZWE     Zimbabwe  2014   01-01-14
# 4809  ZWE     Zimbabwe  2014   01-12-14
# 4810  ZWE     Zimbabwe  2015   02-01-15
# 4811  ZWE     Zimbabwe  2016   14-12-16
# 4812  ZWE     Zimbabwe  2017   15-11-17
# 4813  ZWE     Zimbabwe  2017   18-02-17
# 4814  ZWE     Zimbabwe  2017   01-01-17
# 4815  ZWE     Zimbabwe  2017   26-02-17
#
#                                              Event Name  Hazard Category  \
# 0                                                   NaN  Weather related
# 1                                                   NaN      Geophysical
# 2                                                   NaN  Weather related
# 3                                                   NaN  Weather related
# 4                                                   NaN      Geophysical
# 5                                                   NaN  Weather related
# 6                                                   NaN  Weather related
# 7                                                   NaN      Geophysical
# 8                                                   NaN  Weather related
# 9                                                   NaN  Weather related
# 10                                                  NaN  Weather related
# 11                                                  NaN  Weather related
# 12                                                  NaN  Weather related
# 13                                                  NaN  Weather related
# 14                                                  NaN  Weather related
# 15                                                  NaN      Geophysical
# 16                                                  NaN  Weather related
# 17                                                  NaN  Weather related
# 18                                                  NaN  Weather related
# 19                                                  NaN  Weather related
# 20                                                  NaN  Weather related
# 21                                                  NaN  Weather related
# 22                                                  NaN  Weather related
# 23                          March Floods and Landslides  Weather related
# 24                                    April Flash Flood  Weather related
# 25                   Afghanistan November Heavy Raining  Weather related
# 26                                   August Flash Flood  Weather related
# 27    Ghor, Badakhastan, Hiratn, Kundus, Parwan floo...  Weather related
# 28    Waris, Yakawlang, Shibar districts and Bamyan ...  Weather related
# 29                          Guzargah-e-Nur flash floods  Weather related
# ...                                                 ...              ...
# 4786        Zambia: Flood - Chilubi Island - 16/11/2017  Weather related
# 4787         Zambia: Storm - North Western - 31/12/2017  Weather related
# 4788         Zambia: Storm - North Western - 14/12/2017  Weather related
# 4789         Zambia: Earthquake - Northern - 24/02/2017      Geophysical
# 4790           Zambia: Flood - 4 provinces - 07/02/2017  Weather related
# 4791      Zambia: Flood - Luangwa, Zambezi - 13/03/2017  Weather related
# 4792                                                NaN  Weather related
# 4793                                                NaN  Weather related
# 4794                          Zimbabwe January Flooding  Weather related
# 4795                                Goromonzi landslide  Weather related
# 4796                                   Insiza hailstorm  Weather related
# 4797                              Gokwe North hailstorm  Weather related
# 4798                                  Mwenezi hailstorm  Weather related
# 4799                                   Matobo hailstorm  Weather related
# 4800                          Mt Darwin hailstorm (Dec)  Weather related
# 4801                                   Mutare hailstorm  Weather related
# 4802                                   Buhera hailstorm  Weather related
# 4803                                   Mutasa hailstorm  Weather related
# 4804                                   Nyanga hailstorm  Weather related
# 4805                                      Mutare floods  Weather related
# 4806                                 Chipinge veld fire  Weather related
# 4807                            Tokwe Mukorsi Dam flood  Weather related
# 4808                          Mt Darwin hailstorm (Jan)  Weather related
# 4809                                       Mutare flood  Weather related
# 4810                               North-eastern floods  Weather related
# 4811              Floods in Matabeleland North Province  Weather related
# 4812        Zimbabwe: Hailstorm - Bulawayo - 15/11/2017  Weather related
# 4813  Botswana; Mozambique; South Africa; Zimbabwe: ...  Weather related
# 4814              Zimbabwe: Rainy season - January 2017  Weather related
# 4815       Zimbabwe - Landslide - Musamiri - 26/02/2017  Weather related
#
#               Hazard Type  New Displacements
# 0                   Flood              180.0
# 1              Earthquake             3250.0
# 2     Extreme temperature                NaN
# 3                   Flood            25185.0
# 4              Earthquake             3250.0
# 5                   Flood                NaN
# 6       Wet mass movement                NaN
# 7              Earthquake             1000.0
# 8                   Flood                NaN
# 9       Wet mass movement                NaN
# 10                  Flood            70000.0
# 11      Wet mass movement                NaN
# 12                  Flood             3000.0
# 13    Extreme temperature             1656.0
# 14      Wet mass movement              546.0
# 15             Earthquake             5082.0
# 16    Extreme temperature              714.0
# 17    Extreme temperature              637.0
# 18      Wet mass movement              238.0
# 19                  Flood             4685.0
# 20                  Flood            12589.0
# 21                  Flood             1872.0
# 22                  Flood             1500.0
# 23                  Flood              749.0
# 24                  Flood              270.0
# 25      Wet mass movement              391.0
# 26                  Flood             4880.0
# 27                  Flood             8880.0
# 28      Wet mass movement              244.0
# 29                  Flood             5775.0
# ...                   ...                ...
# 4786                Flood                5.0
# 4787                Storm              196.0
# 4788                Storm              167.0
# 4789           Earthquake               54.0
# 4790                Flood             2352.0
# 4791                Flood               49.0
# 4792                Flood                NaN
# 4793                Flood                NaN
# 4794                Flood            43809.0
# 4795    Wet mass movement                4.0
# 4796                Storm               60.0
# 4797                Storm              376.0
# 4798                Storm              760.0
# 4799                Storm               40.0
# 4800                Storm               80.0
# 4801                Storm               60.0
# 4802                Storm               64.0
# 4803                Storm               92.0
# 4804                Storm               60.0
# 4805                Flood               90.0
# 4806             Wildfire               16.0
# 4807                Flood            20000.0
# 4808                Storm              800.0
# 4809                Flood                8.0
# 4810                Storm              800.0
# 4811                Flood              400.0
# 4812                Storm              200.0
# 4813                Storm             1577.0
# 4814                Flood             8485.0
# 4815    Wet mass movement                8.0
#
# [4816 rows x 8 columns]

# %%
p.to_csv('displace.csv')

# %%
len(lat)
import numpy as np
np.savetxt("lat.csv", lon, delimiter=",", fmt='%s')
