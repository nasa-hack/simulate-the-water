# %%
import pandas as pd
data = open('agr.csv','r')
#print(data)
p = pd.read_csv(data)
p.head()
#p['Name']
# Out:
#           Name  Year  Conflict Stock Displacement  Conflict New Displacements  \
# 0  Afghanistan  2008                          NaN                         NaN
# 1  Afghanistan  2009                     297000.0                         NaN
# 2  Afghanistan  2010                     352000.0                    102000.0
# 3  Afghanistan  2011                     450000.0                    186000.0
# 4  Afghanistan  2012                     492000.0                    100000.0
#
#    Disaster New Displacements
# 0                      3400.0
# 1                     28000.0
# 2                     71000.0
# 3                      3000.0
# 4                     30000.0

# %%
p.Name=p.Name.fillna('Afghanistan')

# %%
n=p['Name']
l=[]
for name in n:
    l.append(name)
m=list(set(l))

# %%
from geopy.geocoders import Nominatim
lat=[]
lon=[]
for names in l:
    geolocator = Nominatim(user_agent="specify_your_app_name_here")
    location = geolocator.geocode(names,timeout=1000000)
    #print((location.latitude, location.longitude))
    if location:
        lat.append(location.latitude)
        lon.append(location.longitude)
    else:
        lat.append(33.7680065)
        lon.append(66.2385139)

# %%
# from geopy.exc import GeocoderTimedOut

# geolocator = Nominatim()
# try:
#     location = geolocator.geocode("Angullia",timeout=None)
#     print(location.latitude, location.longitude)
# except GeocoderTimedOut as e:
#     print("Error: geocode failed on input %s with message %s"%(my_address, e.message))

# %%
import pandas as pd
se = pd.Series(lat)
p['latitude'] = se.values


#p.append(lat,column=['latitude'])
#p.append(lon,column=['longitude'])

# %%
se = pd.Series(lon)
p['longitude'] = se.values

# %%
p
# Out:
#                      Name  Year  Conflict Stock Displacement  \
# 0             Afghanistan  2008                          NaN
# 1             Afghanistan  2009                     297000.0
# 2             Afghanistan  2010                     352000.0
# 3             Afghanistan  2011                     450000.0
# 4             Afghanistan  2012                     492000.0
# 5             Afghanistan  2013                     631000.0
# 6             Afghanistan  2014                     805000.0
# 7             Afghanistan  2015                    1174000.0
# 8             Afghanistan  2016                    1553000.0
# 9             Afghanistan  2017                    1286000.0
# 10                 Angola  2009                          NaN
# 11                 Angola  2010                          NaN
# 12                 Angola  2011                          NaN
# 13                 Angola  2012                          NaN
# 14                 Angola  2013                          NaN
# 15                 Angola  2015                          NaN
# 16                 Angola  2016                          NaN
# 17                 Angola  2017                          NaN
# 18               Anguilla  2017                          NaN
# 19                Albania  2009                          NaN
# 20                Albania  2010                          NaN
# 21                Albania  2012                          NaN
# 22                Albania  2013                          NaN
# 23                Albania  2014                          NaN
# 24                Albania  2015                          NaN
# 25                Albania  2016                          NaN
# 26                Albania  2017                          NaN
# 27   United Arab Emirates  2017                          NaN
# 28              Argentina  2008                          NaN
# 29              Argentina  2009                          NaN
# ..                    ...   ...                          ...
# 932           Yemen, Rep.  2015                    2509000.0
# 933           Yemen, Rep.  2016                    1974000.0
# 934           Yemen, Rep.  2017                    2014000.0
# 935          South Africa  2008                          NaN
# 936          South Africa  2009                          NaN
# 937          South Africa  2010                          NaN
# 938          South Africa  2011                          NaN
# 939          South Africa  2012                          NaN
# 940          South Africa  2013                          NaN
# 941          South Africa  2014                          NaN
# 942          South Africa  2015                          NaN
# 943          South Africa  2016                          NaN
# 944          South Africa  2017                          NaN
# 945                Zambia  2008                          NaN
# 946                Zambia  2009                          NaN
# 947                Zambia  2010                          NaN
# 948                Zambia  2011                          NaN
# 949                Zambia  2013                          NaN
# 950                Zambia  2014                          NaN
# 951                Zambia  2015                          NaN
# 952                Zambia  2017                          NaN
# 953              Zimbabwe  2009                          NaN
# 954              Zimbabwe  2010                          NaN
# 955              Zimbabwe  2011                          NaN
# 956              Zimbabwe  2012                          NaN
# 957              Zimbabwe  2013                          NaN
# 958              Zimbabwe  2014                          NaN
# 959              Zimbabwe  2015                          NaN
# 960              Zimbabwe  2016                          NaN
# 961              Zimbabwe  2017                          NaN
#
#      Conflict New Displacements  Disaster New Displacements   latitude  \
# 0                           NaN                      3400.0  33.768006
# 1                           NaN                     28000.0  33.768006
# 2                      102000.0                     71000.0  33.768006
# 3                      186000.0                      3000.0  33.768006
# 4                      100000.0                     30000.0  33.768006
# 5                      124000.0                     15000.0  33.768006
# 6                      156000.0                     13000.0  33.768006
# 7                      335000.0                     71000.0  33.768006
# 8                      653000.0                      7400.0  33.768006
# 9                      474000.0                     27000.0  33.768006
# 10                          NaN                     86000.0 -11.877577
# 11                          NaN                     79000.0 -11.877577
# 12                          NaN                    227000.0 -11.877577
# 13                          NaN                      6400.0 -11.877577
# 14                          NaN                      2500.0 -11.877577
# 15                          NaN                      5600.0 -11.877577
# 16                          NaN                     19000.0 -11.877577
# 17                          NaN                     14000.0 -11.877577
# 18                          NaN                       500.0  18.195495
# 19                          NaN                       150.0  41.000028
# 20                          NaN                         NaN  41.000028
# 21                          NaN                         NaN  41.000028
# 22                          NaN                       450.0  41.000028
# 23                          NaN                        24.0  41.000028
# 24                          NaN                      4200.0  41.000028
# 25                          NaN                      3100.0  41.000028
# 26                          NaN                      3500.0  41.000028
# 27                          NaN                       850.0  24.000249
# 28                          NaN                       640.0 -34.996496
# 29                          NaN                         NaN -34.996496
# ..                          ...                         ...        ...
# 932                   2175000.0                     83000.0  33.768006
# 933                    478000.0                     45000.0  33.768006
# 934                    160000.0                        13.0  33.768006
# 935                         NaN                      3500.0 -28.816624
# 936                         NaN                     20000.0 -28.816624
# 937                         NaN                      6000.0 -28.816624
# 938                         NaN                     52000.0 -28.816624
# 939                         NaN                      2000.0 -28.816624
# 940                         NaN                     18000.0 -28.816624
# 941                         NaN                      3500.0 -28.816624
# 942                         NaN                        14.0 -28.816624
# 943                         NaN                     12000.0 -28.816624
# 944                         NaN                     15000.0 -28.816624
# 945                         NaN                      5800.0 -14.518624
# 946                         NaN                     54000.0 -14.518624
# 947                         NaN                       150.0 -14.518624
# 948                         NaN                         NaN -14.518624
# 949                         NaN                      5500.0 -14.518624
# 950                         NaN                     26000.0 -14.518624
# 951                         NaN                        25.0 -14.518624
# 952                         NaN                      2800.0 -14.518624
# 953                     15000.0                         NaN -18.455496
# 954                         NaN                         NaN -18.455496
# 955                         NaN                         NaN -18.455496
# 956                       280.0                         NaN -18.455496
# 957                         NaN                     44000.0 -18.455496
# 958                         NaN                     23000.0 -18.455496
# 959                         NaN                       800.0 -18.455496
# 960                         NaN                       400.0 -18.455496
# 961                         NaN                     10000.0 -18.455496
#
#      longitude
# 0    66.238514
# 1    66.238514
# 2    66.238514
# 3    66.238514
# 4    66.238514
# 5    66.238514
# 6    66.238514
# 7    66.238514
# 8    66.238514
# 9    66.238514
# 10   17.569124
# 11   17.569124
# 12   17.569124
# 13   17.569124
# 14   17.569124
# 15   17.569124
# 16   17.569124
# 17   17.569124
# 18  -63.075023
# 19   19.999962
# 20   19.999962
# 21   19.999962
# 22   19.999962
# 23   19.999962
# 24   19.999962
# 25   19.999962
# 26   19.999962
# 27   53.999483
# 28  -64.967282
# 29  -64.967282
# ..         ...
# 932  66.238514
# 933  66.238514
# 934  66.238514
# 935  24.991639
# 936  24.991639
# 937  24.991639
# 938  24.991639
# 939  24.991639
# 940  24.991639
# 941  24.991639
# 942  24.991639
# 943  24.991639
# 944  24.991639
# 945  27.559916
# 946  27.559916
# 947  27.559916
# 948  27.559916
# 949  27.559916
# 950  27.559916
# 951  27.559916
# 952  27.559916
# 953  29.746841
# 954  29.746841
# 955  29.746841
# 956  29.746841
# 957  29.746841
# 958  29.746841
# 959  29.746841
# 960  29.746841
# 961  29.746841
#
# [962 rows x 7 columns]

# %%
p.to_csv('displace.csv')
